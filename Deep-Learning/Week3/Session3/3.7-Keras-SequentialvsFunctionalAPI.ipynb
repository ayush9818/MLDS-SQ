# %% [markdown]
# # Keras Sequential vs Functional API

# %%
#!pip install pydot
# Out:
# Requirement already satisfied: pydot in /opt/homebrew/anaconda3/lib/python3.11/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pydot) (3.0.9)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
from tensorflow.keras import Input, Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense,concatenate
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ### Sequential API
#
# The sequential API allows you to create models layer-by-layer for most problems. It is limited in that it does not allow you to create models that share layers or have multiple inputs or outputs.

# %%
model = Sequential()
model.add(Dense(20, activation='relu', input_shape=(10,)))
model.add(Dense(20, activation='relu'))
model.add(Dense(10, activation='softmax'))   
plot_model(model,show_shapes = True, show_layer_names = True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                220
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_2 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 850 (3.32 KB)
# Trainable params: 850 (3.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Functional API
#
# The Keras functional API provides a more flexible way for defining models.
#
# It specifically allows you to define multiple input or output models as well as models that share layers. More than that, it allows you to define adhoc acyclic network graphs.

# %%
inputs = Input(shape=(10,))

# A layer instance is callable on a tensor, and returns a tensor.
x = Dense(20, activation='relu')(inputs)
x = Dense(20, activation='relu')(x)

predictions = Dense(10, activation='softmax')(x)

# Instantiate the model given inputs and outputs.
model = Model(inputs=inputs, outputs=predictions)
plot_model(model,show_shapes = True, show_layer_names = True)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense_3 (Dense)             (None, 20)                220
#
#  dense_4 (Dense)             (None, 20)                420
#
#  dense_5 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 850 (3.32 KB)
# Trainable params: 850 (3.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
