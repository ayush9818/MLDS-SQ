# %% [markdown]
# # Lab 5.2 Object Detection
# We will use Haar Cascade Classfier to detect specific objects in an image in Python.

# %% [markdown]
# ### Install cmake and OpenCV on your device
# #### MacOS
# Step 1. Install `cmake`
# ```
# brew install cmake
# ```
# Step 2. Install `opencv-python`
# ```
# conda activate [your_conda_env]
# pip install opencv-python
# ```
#
# #### Deepdish
# `cmake` should have already been installed for you.
# Run
# ```
# conda activate [your_conda_env]
# pip install opencv-python
# ```

# %% [markdown]
# ## Demo - Car Plate Detection

# %%
import os

import cv2
import matplotlib.pyplot as plt

def detect(image_name):
  # Load image and cascade classifier
  img = cv2.imread(image_name)
  plate_cascade = cv2.CascadeClassifier('haarcascade_russian_plate_number.xml')

  # Convert image to grayscale
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

  # Detect license plates in image
  plates = plate_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

  # Draw bounding boxes around license plates
  for (x, y, w, h) in plates:
      cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

  # Display image with bounding boxes
  plt.imshow(img)

# %%
detect(os.path.abspath("cars1.jpeg"))

# %%
detect(os.path.abspath("cars2.jpeg"))

# %%
detect(os.path.abspath("cars3.jpeg"))

# %% [markdown]
# ## TODOs
# 1. Find a trained model for specific objects [here](https://github.com/opencv/opencv/tree/master/data/haarcascades).
# 2. Find from the Internet some example images that contain such objects and try to detect them in the images.
